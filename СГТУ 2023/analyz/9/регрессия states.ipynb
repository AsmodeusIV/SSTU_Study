# %%
import pandas as pd

# %%
df = pd.read_excel('states.xlsx')
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                     state  metro_res  white  hs_grad  poverty  female_house
# 0                 Alabama       55.4   71.3     79.9     14.6          14.2
# 1                  Alaska       65.6   70.8     90.6      8.3          10.8
# 2                 Arizona       88.2   87.7     83.8     13.3          11.1
# 3                Arkansas       52.5   81.0     80.9     18.0          12.1
# 4              California       94.4   77.5     81.1     12.8          12.6
# 5                Colorado       84.5   90.2     88.7      9.4           9.6
# 6             Connecticut       87.7   85.4     87.5      7.8          12.1
# 7                Delaware       80.1   76.3     88.7      8.1          13.1
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['hs_grad'],df['poverty'])
plt.xlabel("уровень образования")
plt.ylabel("уровень бедности")
plt.show()

# %%
import statsmodels.api as sm

# %%
#определим зависимую переменную
y = df['poverty']

#определим независимую переменную
x = df[['hs_grad']]

#add constant to predictor variables
x = sm.add_constant (x)

#выбор модели линейной регрессии, использующую метод наименьших квадратов
model = sm. OLS (y, x). fit ()

#сводная таблица модели
print(model. summary ())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                poverty   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     61.81
# Date:                Wed, 22 Nov 2023   Prob (F-statistic):           3.11e-10
# Time:                        04:42:54   Log-Likelihood:                -108.74
# No. Observations:                  51   AIC:                             221.5
# Df Residuals:                      49   BIC:                             225.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         64.7810      6.803      9.523      0.000      51.111      78.451
# ...

# %% [markdown]
# Получили уравнение регрессии
#
# Poverty = 64,78-0,62* hs_grad

# %% [markdown]
# Вот как интерпретировать остальную часть сводки модели:
#
# P>|t|: это значение p, связанное с коэффициентами модели. Поскольку p-значение для часов (0,000) значительно меньше 0,05, мы можем сказать, что существует статистически значимая связь между часами и оценкой .
#
# R-квадрат: это число говорит нам о том, какую процентную вариацию в уровне бедности можно объяснить уровнем образования (55,8%). В целом, чем больше значение R-квадрата регрессионной модели, тем лучше независимые переменные способны предсказать значение переменной отклика.
#
# F-статистика и p-значение: F-статистика  и соответствующее значение p (Prob (F-statistic)) говорят нам об общей значимости регрессионной модели, т. е. о том, полезны ли независимые переменные в модели для объяснения вариации. в переменной ответа. Поскольку p-значение в этом примере меньше 0,05, наша модель является статистически значимой
